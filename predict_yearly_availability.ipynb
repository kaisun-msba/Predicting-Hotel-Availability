# %%
import pandas as pd
import numpy as np

# %%
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
import xgboost
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
data=pd.read_csv("train.csv")

# %%
data.head()
# Out:
#       id     region  latitude  longitude accommodation_type  cost  \
# 0  13232  Manhattan  40.71854  -74.00439    Entire home/apt   170
# 1    246   Brooklyn  40.64446  -73.95030    Entire home/apt    65
# 2  19091     Queens  40.78573  -73.81062       Private room    85
# 3  34305  Manhattan  40.73863  -73.98002       Private room   210
# 4    444  Manhattan  40.82426  -73.94630        Shared room    75
#
#    minimum_nights  number_of_reviews  reviews_per_month   owner_id  \
# 0               5                  7               0.56     929983
# 1               3                238               2.30     281764
# 2               1                  0                NaN   19923341
# 3              30                  0                NaN  200380610
# 4               3                 38               0.42     745069
#
#    owned_hotels  yearly_availability
# 0             1                    0
# 1             1                    0
# 2             1                    1
# 3            65                    1
# 4             3                    1

# %%
data.describe()
# Out:
#                  id     latitude    longitude         cost  minimum_nights  \
# count   2870.000000  2870.000000  2870.000000  2870.000000     2870.000000
# mean   26760.657143    40.731224   -73.950158   195.943206       11.530314
# std    14140.930062     0.054942     0.049745   406.184714       37.972339
# min        0.000000    40.507080   -74.242850    10.000000        1.000000
# 25%    15931.750000    40.692462   -73.984003    75.000000        1.000000
# 50%    28946.500000    40.728250   -73.956720   120.000000        3.000000
# 75%    38478.500000    40.762658   -73.934202   200.000000        6.000000
# max    48893.000000    40.898730   -73.721730  9999.000000      999.000000
#
#        number_of_reviews  reviews_per_month      owner_id  owned_hotels  \
# count        2870.000000        2194.000000  2.870000e+03   2870.000000
# mean           16.315331           1.157502  7.202195e+07      8.411498
# std            32.481722           1.355028  8.076516e+07     27.105522
# min             0.000000           0.010000  2.787000e+03      1.000000
# 25%             1.000000           0.240000  7.388002e+06      1.000000
# 50%             4.000000           0.650000  3.352708e+07      1.000000
# 75%            16.000000           1.530000  1.207625e+08      3.000000
# max           395.000000          10.370000  2.738123e+08    327.000000
#
#        yearly_availability
# count          2870.000000
# mean              0.498606
# std               0.500085
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               1.000000
# max               1.000000

# %%
data.dtypes
# it seems like categorical variables are region, accomodation_type, owner_id
# Out:
# id                       int64
# region                  object
# latitude               float64
# longitude              float64
# accommodation_type      object
# cost                     int64
# minimum_nights           int64
# number_of_reviews        int64
# reviews_per_month      float64
# owner_id                 int64
# owned_hotels             int64
# yearly_availability      int64
# dtype: object

# %%
# check whether there's class imbalance 
data['yearly_availability'].value_counts()
# Out:
# 0    1439
# 1    1431
# Name: yearly_availability, dtype: int64

# %%
# Checking if any column have nulls
data.isnull().sum(axis=0)
# Out:
# id                     0
# region                 0
# latitude               0
# longitude              0
# accommodation_type     0
# cost                   0
# minimum_nights         0
# number_of_reviews      0
# reviews_per_month      0
# owner_id               0
# owned_hotels           0
# yearly_availability    0
# dtype: int64

# %%
data['reviews_per_month'] = data['reviews_per_month'].fillna(0)

# %%
# it looks like the data is within nyc, can drop latitude/longitude later
# can use target encoding for region
data['region'].value_counts()
# Out:
# Manhattan        1333
# Brooklyn         1075
# Queens            370
# Bronx              78
# Staten Island      14
# Name: region, dtype: int64

# %%
# see how many unique owners are there
data['owner_id'].value_counts().unique().sum()
# high cardinality - target encoding
# Out:
# 208

# %%
def target_encoding(df, cat):
    y_avg=data['yearly_availability'].mean()
    y_reg=data.groupby(cat)['yearly_availability'].mean()
    num_reg=data.groupby(cat).size()
    smooth=(num_reg*y_reg+10*y_avg)/(num_reg+10)
    cat_target=cat+'_target'
    data[cat_target]=data[cat].map(smooth)

# %%
target_encoding(data,'owner_id')

# %%
target_encoding(data,'region')

# %%
data.head()
# Out:
#       id     region  latitude  longitude accommodation_type  cost  \
# 0  13232  Manhattan  40.71854  -74.00439    Entire home/apt   170
# 1    246   Brooklyn  40.64446  -73.95030    Entire home/apt    65
# 2  19091     Queens  40.78573  -73.81062       Private room    85
# 3  34305  Manhattan  40.73863  -73.98002       Private room   210
# 4    444  Manhattan  40.82426  -73.94630        Shared room    75
#
#    minimum_nights  number_of_reviews  reviews_per_month   owner_id  \
# 0               5                  7               0.56     929983
# 1               3                238               2.30     281764
# 2               1                  0               0.00   19923341
# 3              30                  0               0.00  200380610
# 4               3                 38               0.42     745069
#
#    owned_hotels  yearly_availability  owner_id_target  region_target
# 0             1                    0         0.453278       0.488448
# 1             1                    0         0.453278       0.447913
# 2             1                    1         0.544188       0.618384
# 3            65                    1         0.871438       0.488448
# 4             3                    1         0.544188       0.488448

# %%
# low cardinality, can use one-hot encoding 
data['accommodation_type'].value_counts()
# Out:
# Private room       1225
# Entire home/apt    1002
# Shared room         643
# Name: accommodation_type, dtype: int64

# %%
data=pd.get_dummies(data, prefix=['acc'], columns=['accommodation_type'],drop_first=True)

# %%
original_data=data.copy()

# %%
data = data.drop(['id','region','latitude','longitude','owner_id'], axis = 1)

# %%
data.head()
# Out:
#    cost  minimum_nights  number_of_reviews  reviews_per_month  owned_hotels  \
# 0   170               5                  7               0.56             1
# 1    65               3                238               2.30             1
# 2    85               1                  0               0.00             1
# 3   210              30                  0               0.00            65
# 4    75               3                 38               0.42             3
#
#    yearly_availability  owner_id_target  region_target  acc_Private room  \
# 0                    0         0.453278       0.488448                 0
# 1                    0         0.453278       0.447913                 0
# 2                    1         0.544188       0.618384                 1
# 3                    1         0.871438       0.488448                 1
# 4                    1         0.544188       0.488448                 0
#
#    acc_Shared room
# 0                0
# 1                0
# 2                0
# 3                0
# 4                1

# %%
original_data.head()
# Out:
#       id     region  latitude  longitude  cost  minimum_nights  \
# 0  13232  Manhattan  40.71854  -74.00439   170               5
# 1    246   Brooklyn  40.64446  -73.95030    65               3
# 2  19091     Queens  40.78573  -73.81062    85               1
# 3  34305  Manhattan  40.73863  -73.98002   210              30
# 4    444  Manhattan  40.82426  -73.94630    75               3
#
#    number_of_reviews  reviews_per_month   owner_id  owned_hotels  \
# 0                  7               0.56     929983             1
# 1                238               2.30     281764             1
# 2                  0               0.00   19923341             1
# 3                  0               0.00  200380610            65
# 4                 38               0.42     745069             3
#
#    yearly_availability  owner_id_target  region_target  acc_Private room  \
# 0                    0         0.453278       0.488448                 0
# 1                    0         0.453278       0.447913                 0
# 2                    1         0.544188       0.618384                 1
# 3                    1         0.871438       0.488448                 1
# 4                    1         0.544188       0.488448                 0
#
#    acc_Shared room
# 0                0
# 1                0
# 2                0
# 3                0
# 4                1

# %%
X=data.drop(columns='yearly_availability',axis=0)
y=data['yearly_availability']

# %%
scoring={'accuracy':make_scorer(accuracy_score),
        'f1_score':make_scorer(f1_score)}

# %%
'''
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
import xgboost
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
'''
svc=LinearSVC(verbose=0,dual=False)
naive=GaussianNB()
rf=RandomForestClassifier()
xgb=xgboost.XGBClassifier(eval_metric='auc',use_label_encoder=False)

# %%
def model_evaluation(model,X,y):
    model_cv=cross_validate(model,X,y,cv=10,scoring=scoring)
    scoring_table=pd.DataFrame({'Accuracy':model_cv['test_accuracy'].mean(),
                               'F1 Score': model_cv['test_f1_score'].mean()},
                              index=[str(model)])
    return scoring_table

# %%
model_evaluation(svc,X,y)
# Out:
#                        Accuracy  F1 Score
# LinearSVC(dual=False)  0.997561  0.997554

# %%
model_evaluation(naive,X,y)
# Out:
#               Accuracy  F1 Score
# GaussianNB()  0.951568  0.951461

# %%
model_evaluation(rf,X,y)
# Out:
#                           Accuracy  F1 Score
# RandomForestClassifier()   0.99547  0.995465

# %%
model_evaluation(xgb,X,y)
# Out:
#                                                     Accuracy  F1 Score
# XGBClassifier(base_score=None, booster=None, co...  0.996516  0.996501

# %%
# looking at the performances of these models, it seems like svc has the best performance 
# with xgb and rf followed behind closely.
svc.fit(X,y)
# Out:
# LinearSVC(dual=False)

# %%
test=pd.read_csv('test.csv')

# %%
test.head()
# Out:
#       id     region  latitude  longitude accommodation_type  cost  \
# 0  19215   Brooklyn  40.70912  -73.94513        Shared room   135
# 1  36301   Brooklyn  40.57646  -73.96641    Entire home/apt    69
# 2  40566  Manhattan  40.76616  -73.98228       Private room   225
# 3  33694  Manhattan  40.77668  -73.94587        Shared room   125
# 4  28873  Manhattan  40.80279  -73.94450    Entire home/apt    43
#
#    minimum_nights  number_of_reviews  reviews_per_month   owner_id  \
# 0               2                 22               0.66    4360212
# 1               2                  8               0.90  181356989
# 2              30                  0               0.00   13773574
# 3              30                  9               0.82    6788748
# 4               1                 13               0.72  105061915
#
#    owned_hotels
# 0             1
# 1             2
# 2            12
# 3             1
# 4             2

# %%
data.head()
# Out:
#    cost  minimum_nights  number_of_reviews  reviews_per_month  owned_hotels  \
# 0   170               5                  7               0.56             1
# 1    65               3                238               2.30             1
# 2    85               1                  0               0.00             1
# 3   210              30                  0               0.00            65
# 4    75               3                 38               0.42             3
#
#    yearly_availability  owner_id_target  region_target  acc_Private room  \
# 0                    0         0.453278       0.488448                 0
# 1                    0         0.453278       0.447913                 0
# 2                    1         0.544188       0.618384                 1
# 3                    1         0.871438       0.488448                 1
# 4                    1         0.544188       0.488448                 0
#
#    acc_Shared room
# 0                0
# 1                0
# 2                0
# 3                0
# 4                1

# %%
test['reviews_per_month'] = test['reviews_per_month'].fillna(0)

# %%
test=pd.get_dummies(test, prefix=['acc'], columns=['accommodation_type'],drop_first=True)

# %%
original_data.head()
# Out:
#       id     region  latitude  longitude  cost  minimum_nights  \
# 0  13232  Manhattan  40.71854  -74.00439   170               5
# 1    246   Brooklyn  40.64446  -73.95030    65               3
# 2  19091     Queens  40.78573  -73.81062    85               1
# 3  34305  Manhattan  40.73863  -73.98002   210              30
# 4    444  Manhattan  40.82426  -73.94630    75               3
#
#    number_of_reviews  reviews_per_month   owner_id  owned_hotels  \
# 0                  7               0.56     929983             1
# 1                238               2.30     281764             1
# 2                  0               0.00   19923341             1
# 3                  0               0.00  200380610            65
# 4                 38               0.42     745069             3
#
#    yearly_availability  owner_id_target  region_target  acc_Private room  \
# 0                    0         0.453278       0.488448                 0
# 1                    0         0.453278       0.447913                 0
# 2                    1         0.544188       0.618384                 1
# 3                    1         0.871438       0.488448                 1
# 4                    1         0.544188       0.488448                 0
#
#    acc_Shared room
# 0                0
# 1                0
# 2                0
# 3                0
# 4                1

# %%
target_data_region=original_data[['region','region_target']].drop_duplicates()

# %%
target_data_owner_id=original_data[['owner_id','owner_id_target']].drop_duplicates()

# %%
join_df=pd.merge(test,target_data_region,on='region',how='left')

# %%
join_df_2=pd.merge(join_df,target_data_owner_id,on='owner_id',how='left')

# %%
# Checking if any column have nulls
join_df_2.isnull().sum(axis=0)
# Out:
# id                     0
# region                 0
# latitude               0
# longitude              0
# cost                   0
# minimum_nights         0
# number_of_reviews      0
# reviews_per_month      0
# owner_id               0
# owned_hotels           0
# acc_Private room       0
# acc_Shared room        0
# region_target          0
# owner_id_target      522
# dtype: int64

# %%
join_df_2['owner_id_target'].fillna(data['yearly_availability'].mean(),inplace=True)

# %%
join_df_2.shape
# Out:
# (718, 14)

# %%
join_df_2.head()
# Out:
#       id     region  latitude  longitude  cost  minimum_nights  \
# 0  19215   Brooklyn  40.70912  -73.94513   135               2
# 1  36301   Brooklyn  40.57646  -73.96641    69               2
# 2  40566  Manhattan  40.76616  -73.98228   225              30
# 3  33694  Manhattan  40.77668  -73.94587   125              30
# 4  28873  Manhattan  40.80279  -73.94450    43               1
#
#    number_of_reviews  reviews_per_month   owner_id  owned_hotels  \
# 0                 22               0.66    4360212             1
# 1                  8               0.90  181356989             2
# 2                  0               0.00   13773574            12
# 3                  9               0.82    6788748             1
# 4                 13               0.72  105061915             2
#
#    acc_Private room  acc_Shared room  region_target  owner_id_target
# 0                 0                1       0.447913         0.498606
# 1                 0                0       0.447913         0.498606
# 2                 1                0       0.488448         0.498606
# 3                 0                1       0.488448         0.498606
# 4                 0                0       0.488448         0.498606

# %%
test = join_df_2.drop(['id','region','latitude','longitude','owner_id'], axis = 1)

# %%
test.head()
# Out:
#    cost  minimum_nights  number_of_reviews  reviews_per_month  owned_hotels  \
# 0   135               2                 22               0.66             1
# 1    69               2                  8               0.90             2
# 2   225              30                  0               0.00            12
# 3   125              30                  9               0.82             1
# 4    43               1                 13               0.72             2
#
#    acc_Private room  acc_Shared room  region_target  owner_id_target
# 0                 0                1       0.447913         0.498606
# 1                 0                0       0.447913         0.498606
# 2                 1                0       0.488448         0.498606
# 3                 0                1       0.488448         0.498606
# 4                 0                0       0.488448         0.498606

# %%
join_df_2.head()
# Out:
#       id     region  latitude  longitude  cost  minimum_nights  \
# 0  19215   Brooklyn  40.70912  -73.94513   135               2
# 1  36301   Brooklyn  40.57646  -73.96641    69               2
# 2  40566  Manhattan  40.76616  -73.98228   225              30
# 3  33694  Manhattan  40.77668  -73.94587   125              30
# 4  28873  Manhattan  40.80279  -73.94450    43               1
#
#    number_of_reviews  reviews_per_month   owner_id  owned_hotels  \
# 0                 22               0.66    4360212             1
# 1                  8               0.90  181356989             2
# 2                  0               0.00   13773574            12
# 3                  9               0.82    6788748             1
# 4                 13               0.72  105061915             2
#
#    acc_Private room  acc_Shared room  region_target  owner_id_target
# 0                 0                1       0.447913         0.498606
# 1                 0                0       0.447913         0.498606
# 2                 1                0       0.488448         0.498606
# 3                 0                1       0.488448         0.498606
# 4                 0                0       0.488448         0.498606

# %%
predictions = list(svc.predict(test))
ids = list(join_df_2['id'])
results = pd.DataFrame(list(zip(ids,predictions)), columns = ['id','yearly_availability'])

# %%
results
# Out:
#         id  yearly_availability
# 0    19215                    0
# 1    36301                    0
# 2    40566                    1
# 3    33694                    0
# 4    28873                    0
# ..     ...                  ...
# 713  26801                    0
# 714  20110                    0
# 715  31383                    0
# 716  47135                    1
# 717  13154                    1
#
# [718 rows x 2 columns]

# %%
results.to_csv('submissions.csv',index=False)
